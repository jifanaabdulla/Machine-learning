# %% [markdown]
# ### Logistic regression using titanic dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#check the null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#drop the null value column
data.drop('Cabin',axis=1,inplace=True)#inplace=True'  make changes permanent 
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#to fill next null column 
data.Age.fillna(data.Age.median(),inplace=True)

# %%
#drop the null values
# data = data.dropna()
# data

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#check the null values
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
#remove that null row fare
data.dropna(inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#check the null values
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#check shape
data.shape
# Out:
# (417, 11)

# %%
data.groupby ('Survived').size()
# Out:
# Survived
# 0    265
# 1    152
# dtype: int64

# %%
cleaned_data = data.drop (columns = ['Name','Ticket'], axis = 1)

# %%
cleaned_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0            892         0       3    male  34.5      0      0    7.8292
# 1            893         1       3  female  47.0      1      0    7.0000
# 2            894         0       2    male  62.0      0      0    9.6875
# 3            895         0       3    male  27.0      0      0    8.6625
# 4            896         1       3  female  22.0      1      1   12.2875
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305         0       3    male  27.0      0      0    8.0500
# 414         1306         1       1  female  39.0      0      0  108.9000
# 415         1307         0       3    male  38.5      0      0    7.2500
# 416         1308         0       3    male  27.0      0      0    8.0500
# 417         1309         0       3    male  27.0      1      1   22.3583
#
#     Embarked
# 0          Q
# 1          S
# 2          Q
# 3          S
# 4          S
# ...

# %% [markdown]
# #### To apply logistic regression all the columns should have categorial or numerical values.

# %%
df=pd.get_dummies (cleaned_data ['Sex'], dtype=int)

# %%
df1 = pd.get_dummies (cleaned_data ['Pclass'],drop_first = True,dtype=int)#drop_first=True  it helps in reducing the extra column created during dummy variable creation.

# %%
df1
# Out:
#      2  3
# 0    0  1
# 1    0  1
# 2    1  0
# 3    0  1
# 4    0  1
# ..  .. ..
# 413  0  1
# 414  0  0
# 415  0  1
# 416  0  1
# 417  0  1
#
# [417 rows x 2 columns]

# %%
df2 =pd.get_dummies (cleaned_data ['Embarked'],dtype=int)
df2
# Out:
#      C  Q  S
# 0    0  1  0
# 1    0  0  1
# 2    0  1  0
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 413  0  0  1
# 414  1  0  0
# 415  0  0  1
# 416  0  0  1
# 417  1  0  0
#
# [417 rows x 3 columns]

# %%
modified_data= pd.concat([cleaned_data, df, df1,df2], axis = 1)

# %%
modified_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0            892         0       3    male  34.5      0      0    7.8292
# 1            893         1       3  female  47.0      1      0    7.0000
# 2            894         0       2    male  62.0      0      0    9.6875
# 3            895         0       3    male  27.0      0      0    8.6625
# 4            896         1       3  female  22.0      1      1   12.2875
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305         0       3    male  27.0      0      0    8.0500
# 414         1306         1       1  female  39.0      0      0  108.9000
# 415         1307         0       3    male  38.5      0      0    7.2500
# 416         1308         0       3    male  27.0      0      0    8.0500
# 417         1309         0       3    male  27.0      1      1   22.3583
#
#     Embarked  female  male  2  3  C  Q  S
# 0          Q       0     1  0  1  0  1  0
# ...

# %%
modified_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    int64
#  2   Pclass       417 non-null    int64
#  3   Sex          417 non-null    object
#  4   Age          417 non-null    float64
#  5   SibSp        417 non-null    int64
#  6   Parch        417 non-null    int64
#  7   Fare         417 non-null    float64
#  8   Embarked     417 non-null    object
#  9   female       417 non-null    int64
#  10  male         417 non-null    int64
#  11  2            417 non-null    int64
#  12  3            417 non-null    int64
#  13  C            417 non-null    int64
#  14  Q            417 non-null    int64
#  15  S            417 non-null    int64
# dtypes: float64(2), int64(12), object(2)
# memory usage: 55.4+ KB

# %%
y= modified_data ['Survived']
x= modified_data.drop (['Sex','Survived','PassengerId','Embarked'], axis = 1 )

# %%
x
# Out:
#      Pclass   Age  SibSp  Parch      Fare  female  male  2  3  C  Q  S
# 0         3  34.5      0      0    7.8292       0     1  0  1  0  1  0
# 1         3  47.0      1      0    7.0000       1     0  0  1  0  0  1
# 2         2  62.0      0      0    9.6875       0     1  1  0  0  1  0
# 3         3  27.0      0      0    8.6625       0     1  0  1  0  0  1
# 4         3  22.0      1      1   12.2875       1     0  0  1  0  0  1
# ..      ...   ...    ...    ...       ...     ...   ... .. .. .. .. ..
# 413       3  27.0      0      0    8.0500       0     1  0  1  0  0  1
# 414       1  39.0      0      0  108.9000       1     0  0  0  1  0  0
# 415       3  38.5      0      0    7.2500       0     1  0  1  0  0  1
# 416       3  27.0      0      0    8.0500       0     1  0  1  0  0  1
# 417       3  27.0      1      1   22.3583       0     1  0  1  1  0  0
#
# [417 rows x 12 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 417, dtype: int64

# %%
x.columns = x .columns.astype(str)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =  train_test_split (x,y,test_size=0.1)

# %%
x_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  female  male  2  3  C  Q  S
# 274       3  27.0      0      0    7.2250       0     1  0  1  1  0  0
# 231       1  21.0      0      0   26.5500       1     0  0  0  0  0  1
# 351       2  25.0      0      0   10.5000       0     1  1  0  0  0  1
# 117       3   1.0      1      1   16.7000       1     0  0  1  0  0  1
# 217       1  57.0      1      1  164.8667       0     1  0  0  0  0  1
# ..      ...   ...    ...    ...       ...     ...   ... .. .. .. .. ..
# 266       1  27.0      0      0    0.0000       0     1  0  0  0  0  1
# 163       3  27.0      0      0    7.0000       0     1  0  1  0  0  1
# 348       2  24.0      0      0   13.5000       0     1  1  0  0  0  1
# 365       3  27.0      1      9   69.5500       1     0  0  1  0  0  1
# 138       3  23.0      0      0    8.0500       1     0  0  1  0  0  1
#
# [375 rows x 12 columns]

# %%
x_test
# Out:
#      Pclass    Age  SibSp  Parch      Fare  female  male  2  3  C  Q  S
# 192       3  11.50      1      1   14.5000       0     1  0  1  0  0  1
# 84        2  27.00      0      0   10.7083       0     1  1  0  0  1  0
# 229       2  36.00      0      0   13.0000       0     1  1  0  0  0  1
# 141       1  33.00      0      0  151.5500       1     0  0  0  0  0  1
# 346       2  26.00      0      0   13.0000       0     1  1  0  0  0  1
# 222       2  22.00      0      0   10.5000       1     0  1  0  0  0  1
# 200       3  27.00      0      0   15.5000       1     0  0  1  0  1  0
# 132       3  27.00      0      4   25.4667       1     0  0  1  0  0  1
# 397       1  48.00      1      1   79.2000       1     0  0  0  1  0  0
# 341       3  32.00      0      0    7.5792       0     1  0  1  0  0  1
# 179       1  64.00      0      2   83.1583       1     0  0  0  1  0  0
# 166       1  48.00      0      0   50.4958       0     1  0  0  1  0  0
# ...

# %%
model =LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /home/jifana/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict=model.predict(x_test)

# %%
#accuracy of a model
model.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        19
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42

# %%
cm =confusion_matrix(y_test,y_predict)

# %%
cm
# Out:
# array([[23,  0],
#        [ 0, 19]])
